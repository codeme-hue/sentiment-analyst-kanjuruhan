# %% [markdown]
# <a href="https://colab.research.google.com/github/kardihaekal/sentiment-analyst-kanjuruhan/blob/master/Lexicon_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import io
#
# s3_data = io.BytesIO(response.get('Body').read())
#
# data = pd.read_csv(s3_data, encoding='windows-1252')

# %%
import pandas as pd
import io

df = pd.read_csv('sample_data/Dataset-Kanjuruhan.csv', encoding='utf-8')

# %%
df.head(5)
# df.columns
# Out:
#    Nomor       Name                                             Comment
# 0      1  sintaadela  Pa sigit banyak bgt cobaannya ya😢 yg sebelah j...
# 1      2    hbbl.hsn  Masih kurang banyak, para polisi yang berada d...
# 2      3  dhatmoko16  @hbbl.hsn yes.. apalagi ada dipintu 13... Hati...
# 3      4    gal.gale                                       Mantu idaman
# 4      5     r_diiit                                Sambo gmn min sambo

# %%
#lexicon based
# !pip install VaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: VaderSentiment in /usr/local/lib/python3.9/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from VaderSentiment) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->VaderSentiment) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->VaderSentiment) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->VaderSentiment) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->VaderSentiment) (2.10)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
scores = [analyser.polarity_scores(x) for x in df['Comment']]
print(scores)
df['Compound_Score'] = [x['compound'] for x in scores]
# Out:
# [{'neg': 0.205, 'neu': 0.795, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4019}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.036, 'neu': 0.813, 'pos': 0.151, 'compound': 0.7269}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.154, 'neu': 0.846, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.744, 'neu': 0.256, 'pos': 0.0, 'compound': -0.4404}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.409, 'neu': 0.314, 'pos': 0.277, 'compound': -0.7184}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'compound': -0.2263}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.674, 'neu': 0.326, 'pos': 0.0, 'compound': -0.7351}, {'neg': 0.437, 'neu': 0.563, 'pos': 0.0, 'compound': -0.7351}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.488, 'neu': 0.512, 'pos': 0.0, 'compound': -0.9081}, {'neg': 0.437, 'neu': 0.563, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.027, 'neu': 0.809, 'pos': 0.165, 'compound': 0.9186}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.608, 'neu': 0.392, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.7351}, {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'n ...

# %%
df.head(100)
# Out:
#     Nomor        Name                                             Comment  \
# 0       1   sintaadela  Pa sigit banyak bgt cobaannya ya😢 yg sebelah j...
# 1       2     hbbl.hsn  Masih kurang banyak, para polisi yang berada d...
# 2       3   dhatmoko16  @hbbl.hsn yes.. apalagi ada dipintu 13... Hati...
# 3       4     gal.gale                                       Mantu idaman
# 4       5      r_diiit                                Sambo gmn min sambo
# ..    ...          ...                                                ...
# 95     96  torosutoro3  Kayak gini faktanya katanya Kapolda polisi pel...
# 96     97     dckysty_                            @torosutoro3 Prosedur 😢
# 97     98     ryuu.zet  @somvchhate hahahahaha duid mas ! Kalo ada dui...
# 98     99  nanangsand_                          @torosutoro3 hanya oknum😢
# 99    100    ayubmhd90  Di sini ku lihat yang salah si polisi!!!!!! Se...
#
#     Compound_Score Sentiments
# 0          -0.4767    Negatif
# 1           0.0000     Netral
# 2           0.4019    Positif
# 3           0.0000     Netral
# 4           0.0000     Netral
# ..             ...        ...
# 95          0.9468    Positif
# 96         -0.4767    Negatif
# 97          0.4926    Positif
# 98         -0.4767    Negatif
# 99          0.0000     Netral
#
# [100 rows x 5 columns]

# %%
#compound_score
df.loc[df['Compound_Score'] < 0, 'Sentiments'] = 'Negatif'
df.loc[df['Compound_Score'] == 0, 'Sentiments'] = 'Netral'
df.loc[df['Compound_Score'] > 0, 'Sentiments'] = 'Positif'
df.head(100)
# Out:
#     Nomor        Name                                             Comment  \
# 0       1   sintaadela  Pa sigit banyak bgt cobaannya ya😢 yg sebelah j...
# 1       2     hbbl.hsn  Masih kurang banyak, para polisi yang berada d...
# 2       3   dhatmoko16  @hbbl.hsn yes.. apalagi ada dipintu 13... Hati...
# 3       4     gal.gale                                       Mantu idaman
# 4       5      r_diiit                                Sambo gmn min sambo
# ..    ...          ...                                                ...
# 95     96  torosutoro3  Kayak gini faktanya katanya Kapolda polisi pel...
# 96     97     dckysty_                            @torosutoro3 Prosedur 😢
# 97     98     ryuu.zet  @somvchhate hahahahaha duid mas ! Kalo ada dui...
# 98     99  nanangsand_                          @torosutoro3 hanya oknum😢
# 99    100    ayubmhd90  Di sini ku lihat yang salah si polisi!!!!!! Se...
#
#     Compound_Score Sentiments
# 0          -0.4767    Negatif
# 1           0.0000     Netral
# 2           0.4019    Positif
# 3           0.0000     Netral
# 4           0.0000     Netral
# ..             ...        ...
# 95          0.9468    Positif
# 96         -0.4767    Negatif
# 97          0.4926    Positif
# 98         -0.4767    Negatif
# 99          0.0000     Netral
#
# [100 rows x 5 columns]

# %%
#save
df.to_csv('hasil_lexiconbased.csv', encoding='utf-8', index=False)
